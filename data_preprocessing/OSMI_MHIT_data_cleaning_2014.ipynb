# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
# Rename columns(2014):
cols = ["age","gender", "country", "state", "self_employed",
        "family_history", "treatment", "work_interfere", "no_employees", "remote_work", 
        "tech_company", "benefits", "care_options", "wellness_program", "seek_help", 
        "anonymity", "leave", "mental_health_consequence", "phys_health_consequence", "coworkers", 
        "supervisor", "mental_health_interview", "phys_health_interview", "mental_vs_physical", 
        "obs_consequence", "comments"]

# %%
df_2014 = pd.read_csv(Path('../resources/OSMI_MHIT_survey/2014_OSMI_MHIT.csv'),names=renamed_columns)
df_2014
# Out:
#             self_employed company_size tech_company       tech_role  \
# 0               Timestamp          Age       Gender         Country
# 1      8/27/2014 11:29:31           37       Female   United States
# 2      8/27/2014 11:29:37           44            M   United States
# 3      8/27/2014 11:29:44           32         Male          Canada
# 4      8/27/2014 11:29:46           31         Male  United Kingdom
# ...                   ...          ...          ...             ...
# 1256    9/26/2015 1:07:35           32         Male   United States
# 1257   11/7/2015 12:36:59           34         male   United States
# 1258  11/30/2015 21:25:07           46            f   United States
# 1259    2/1/2016 23:04:31           25         Male   United States
# 1260    6/22/2017 0:39:01           41         Male       Australia
#
#                                             mh_coverage  \
# 0     If you live in the United States, which state ...
# 1                                                    IL
# 2                                                    IN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1256                                                 IL
# 1257                                                 CA
# 1258                                                 NC
# 1259                                                 IL
# 1260                                                NaN
#
#        mh_coverage_awareness                           mh_employer_discussion  \
# 0     Are you self-employed?  Do you have a family history of mental illness?
# 1                        NaN                                               No
# 2                        NaN                                               No
# 3                        NaN                                               No
# 4                        NaN                                              Yes
# ...                      ...                                              ...
# 1256                      No                                              Yes
# 1257                      No                                              Yes
# 1258                      No                                               No
# 1259                      No                                              Yes
# 1260                      No                                               No
#
#                                   mh_resources_provided  \
# 0     Have you sought treatment for a mental health ...
# 1                                                   Yes
# 2                                                    No
# 3                                                    No
# 4                                                   Yes
# ...                                                 ...
# 1256                                                Yes
# 1257                                                Yes
# 1258                                                 No
# 1259                                                Yes
# 1260                                                 No
#
#                                            mh_anonimity  \
# 0     If you have a mental health condition, do you ...
# 1                                                 Often
# 2                                                Rarely
# 3                                                Rarely
# 4                                                 Often
# ...                                                 ...
# 1256                                              Often
# 1257                                          Sometimes
# 1258                                                NaN
# 1259                                          Sometimes
# 1260                                          Sometimes
#
#                                        mh_medical_leave  ...  \
# 0     How many employees does your company or organi...  ...
# 1                                                  6-25  ...
# 2                                        More than 1000  ...
# 3                                                  6-25  ...
# 4                                                26-100  ...
# ...                                                 ...  ...
# 1256                                             26-100  ...
# 1257                                     More than 1000  ...
# 1258                                            100-500  ...
# 1259                                             26-100  ...
# 1260                                           500-1000  ...
#
#      mh_eff_tx_impact_on_work mh_not_eff_tx_impact_on_work age gender  \
# 0                         NaN                          NaN NaN    NaN
# 1                         NaN                          NaN NaN    NaN
# 2                         NaN                          NaN NaN    NaN
# 3                         NaN                          NaN NaN    NaN
# 4                         NaN                          NaN NaN    NaN
# ...                       ...                          ...  ..    ...
# 1256                      NaN                          NaN NaN    NaN
# 1257                      NaN                          NaN NaN    NaN
# 1258                      NaN                          NaN NaN    NaN
# 1259                      NaN                          NaN NaN    NaN
# 1260                      NaN                          NaN NaN    NaN
#
#      country_live live_us_state country_work work_us_state work_position  \
# 0             NaN           NaN          NaN           NaN           NaN
# 1             NaN           NaN          NaN           NaN           NaN
# 2             NaN           NaN          NaN           NaN           NaN
# 3             NaN           NaN          NaN           NaN           NaN
# 4             NaN           NaN          NaN           NaN           NaN
# ...           ...           ...          ...           ...           ...
# 1256          NaN           NaN          NaN           NaN           NaN
# 1257          NaN           NaN          NaN           NaN           NaN
# 1258          NaN           NaN          NaN           NaN           NaN
# 1259          NaN           NaN          NaN           NaN           NaN
# 1260          NaN           NaN          NaN           NaN           NaN
#
#      remote
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 1256    NaN
# 1257    NaN
# 1258    NaN
# 1259    NaN
# 1260    NaN
#
# [1261 rows x 63 columns]

# %%
#data distribution
df_2014.describe()
# Out:
#        prev_mh_discussion  prev_mh_resources  prev_mh_anonimity  \
# count                 0.0                0.0                0.0
# mean                  NaN                NaN                NaN
# std                   NaN                NaN                NaN
# min                   NaN                NaN                NaN
# 25%                   NaN                NaN                NaN
# 50%                   NaN                NaN                NaN
# 75%                   NaN                NaN                NaN
# max                   NaN                NaN                NaN
#
#        prev_mh_discuss_negative_consequences  \
# count                                    0.0
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#        prev_ph_discuss_negative_consequences  prev_mh_discussion_coworkers  \
# count                                    0.0                           0.0
# mean                                     NaN                           NaN
# std                                      NaN                           NaN
# min                                      NaN                           NaN
# 25%                                      NaN                           NaN
# 50%                                      NaN                           NaN
# 75%                                      NaN                           NaN
# max                                      NaN                           NaN
#
#        prev_mh_discussion_supervisors  prev_mh_importance_employer  \
# count                             0.0                          0.0
# mean                              NaN                          NaN
# std                               NaN                          NaN
# min                               NaN                          NaN
# 25%                               NaN                          NaN
# 50%                               NaN                          NaN
# 75%                               NaN                          NaN
# max                               NaN                          NaN
#
#        prev_mh_consequences_coworkers  future_ph_specification  ...  \
# count                             0.0                      0.0  ...
# mean                              NaN                      NaN  ...
# std                               NaN                      NaN  ...
# min                               NaN                      NaN  ...
# 25%                               NaN                      NaN  ...
# 50%                               NaN                      NaN  ...
# 75%                               NaN                      NaN  ...
# max                               NaN                      NaN  ...
#
#        mh_eff_tx_impact_on_work  mh_not_eff_tx_impact_on_work  age  gender  \
# count                       0.0                           0.0  0.0     0.0
# mean                        NaN                           NaN  NaN     NaN
# std                         NaN                           NaN  NaN     NaN
# min                         NaN                           NaN  NaN     NaN
# 25%                         NaN                           NaN  NaN     NaN
# 50%                         NaN                           NaN  NaN     NaN
# 75%                         NaN                           NaN  NaN     NaN
# max                         NaN                           NaN  NaN     NaN
#
#        country_live  live_us_state  country_work  work_us_state  \
# count           0.0            0.0           0.0            0.0
# mean            NaN            NaN           NaN            NaN
# std             NaN            NaN           NaN            NaN
# min             NaN            NaN           NaN            NaN
# 25%             NaN            NaN           NaN            NaN
# 50%             NaN            NaN           NaN            NaN
# 75%             NaN            NaN           NaN            NaN
# max             NaN            NaN           NaN            NaN
#
#        work_position  remote
# count            0.0     0.0
# mean             NaN     NaN
# std              NaN     NaN
# min              NaN     NaN
# 25%              NaN     NaN
# 50%              NaN     NaN
# 75%              NaN     NaN
# max              NaN     NaN
#
# [8 rows x 36 columns]

# %%
#data types and counts
df.info()

# %%
# Re-Code Gender
# recode 'male'
df_2014['gender'].replace(to_replace = ['Male', 'male', 'Male ', 'M', 'm','man', 'Cis male', 'Male.',
                                   'male 9:1 female, roughly', 'Male (cis)', 'Man', 'Sex is male','cis male', 'Malr',
                                   'Dude', "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
                                   'mail', 'M|', 'Male/genderqueer', 'male ','Cis Male', 'Male (trans, FtM)',
                                   'cisdude', 'cis man', 'MALE'],
                     value='male', inplace = True)
# recode 'female'
df_2014['gender'].replace(to_replace = ['Female', 'female', 'I identify as female.', 'female ','Female assigned at birth ',
                                   'F', 'Woman', 'fm', 'f', 'Cis female ', 'Transitioned, M2F',
                                   'Genderfluid (born female)', 'Female or Multi-Gender Femme', 'Female ', 'woman',
                                   'female/woman','Cisgender Female', 'fem',
                                   'Female (props for making this a freeform field, though)',' Female', 'Cis-woman',
                                   'female-bodied; no feelings about gender','AFAB', 'Transgender woman'],
                     value='female', inplace = True)
# recode for nonbinary (including NaN values)
df_201=['gender'].replace(to_replace = ['Bigender', 'non-binary', 'Other/Transfeminine','Androgynous', 'Other',
                                   'nb masculine','none of your business', 'genderqueer', 'Human', 'Genderfluid',
                                   'Enby', 'genderqueer woman', 'mtf', 'Queer', 'Agender', 'Fluid','Nonbinary',
                                   'human', 'Unicorn', 'Genderqueer','Genderflux demi-girl',np.NaN],
                     value='nonbinary', inplace = True)

# verify sucessful coding
print(df['gender'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-db0d1695fea3> in <module>
#       1 # Re-Code Gender
#       2 # recode 'male'
# ----> 3 df['gender'].replace(to_replace = ['Male', 'male', 'Male ', 'M', 'm','man', 'Cis male', 'Male.',
#       4                                    'male 9:1 female, roughly', 'Male (cis)', 'Man', 'Sex is male','cis male', 'Malr',
#       5                                    'Dude', "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
#
# NameError: name 'df' is not defined

# %%
# Drop unusable columns
# drop freeform answer columns
df.drop(['why_why_not', 'why_why_not2'], axis=1, inplace=True)

# drop columns with more than 75% null values
df.drop(['tech_role','mh_coverage_2', 'mh_online_resources','mh_dx_revealed_clients',
         'mh_coworkers_reveal_negative_impact','mh_product_impact','mh_product_impact_perceived',
         'maybe_whats_your_dx','mh_dx_revealed_clients_impact','mh_dx_revealed_coworkers'], axis=1, inplace=True)

# %%
#Determine number of null entries per column
total = df.isnull().sum().sort_values(ascending=False)
percent = df.isnull().sum()/df.isnull().count()
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(40)

# %%
missing_data.tail(40)

# %%
df.head()

# %%
# Examining distribution of data
df['country_live'].value_counts()

# %%
# Selecting rows based on condition (countries with more than 30 responses)
df = df.loc[(df['country_live'] == 'United States of America') | (df['country_live'] == 'United Kingdom') | (df['country_live'] == 'Canada') | (df['country_live'] == 'Germany') | (df['country_live'] == 'Netherlands') | (df['country_live'] == 'Australia')]

# %%
# Examining self-employed data
df['self_employed'].value_counts()

# %%
# Remove self-employed respondents
df = df.loc[(df['self_employed'] == '0')]

# %%
df

# %%
# Add unique identifier column for use in database
df.insert(0, 'new_id', range(1, 1 + len(df)))
df

# %%
# Examining age data
df['age'].value_counts()

# %%
# Convert age to integer
df[["age"]] = df[["age"]].apply(pd.to_numeric)

# %%
# drop ages outside of 'realistic' range (<20 | >100)
# Get names of indexes for which column Age has value less than 20
indexNames = df[df['age'] < 20 ].index

# Delete these row indexes from dataFrame
df.drop(indexNames, inplace=True)

# Get names of indexes for which column Age has value greater than 100
indexNames = df[df['age'] > 99 ].index

# Delete these row indexes from dataFrame
df.drop(indexNames , inplace=True)

# %%
# Examining age to prepare for binning
df['age'].describe()

# %%
# Fill null values in age column with mean
df['age'].fillna(df['age'].mean(), inplace = True)

# %%
# Bin age values into 4 equal sized groupings of the data
pd.qcut(df['age'], q=4)

# %%
#create 4 bins (aka quartiles) and 10 bins (aka deciles) and store the results back in the original dataframe
df['quantile_age_1'] = pd.qcut(df['age'], q=4)
df['quantile_age_2'] = pd.qcut(df['age'], q=10, precision=0)

df.head()

# %%
df.isnull().any()

# %%
# create function to display percent and number of entries per column that are null values
def missing_zero_values_table(df):
    zero_val = (df == 0.00).astype(int).sum(axis=0)
    null_val = df.isnull().sum()
    
    null_val_percent = 100 * df.isnull().sum() / len(df)
    mz_table = pd.concat([zero_val, null_val, null_val_percent], axis=1)
    
    mz_table = mz_table.rename(columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
    mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
    mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
    mz_table['Data Type'] = df.dtypes
    mz_table = mz_table[mz_table.iloc[:,1] != 0].sort_values('% of Total Values',
                                                             ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"
           "There are " + str(mz_table.shape[0]) + " columns that have missing values.")
    # mz_table.to_csv('../missing_and_zero_values.csv', index = False)
    return mz_table

missing_zero_values_table(df)

# %%
# rename df something more descriptive
OSMI_MHIT_mostly_clean_df = df

# %%
# inspect current state of dataframe
OSMI_MHIT_mostly_clean_df.info()

# %%
# inspect individual values of 'mh_coverage_awareness'
OSMI_MHIT_mostly_clean_df['mh_coverage_awareness'].value_counts()

# %%
# fill null values in 'coverage awareness' with 'not sure'
OSMI_MHIT_mostly_clean_df['mh_coverage_awareness'].fillna('I am not sure', inplace = True)

# %%
# inspect values of 'mh_bad_response_workplace'
OSMI_MHIT_mostly_clean_df['mh_bad_response_workplace'].value_counts()

# %%
# fill null values in 'mh_bad_response_workplace' with 'not sure'
OSMI_MHIT_mostly_clean_df['mh_bad_response_workplace'].fillna('Maybe/Not sure', inplace = True)

# %%
# inspect values of 'live_us_state'
OSMI_MHIT_mostly_clean_df['live_us_state'].value_counts()

# %%
# fill null values in 'live_us_state' with 'none'
OSMI_MHIT_mostly_clean_df['live_us_state'].fillna('none', inplace = True)

# fill null values in 'work_us_state' with 'none'
OSMI_MHIT_mostly_clean_df['work_us_state'].fillna('none', inplace = True)

# %%
# inspect current state of dataframe
OSMI_MHIT_mostly_clean_df.info()

# %%
# export 'mostly cleaned' dataframe to csv file
OSMI_MHIT_mostly_clean_df.to_csv('../resources/OSMI_MHIT_mostly_clean_2017.csv', index = False)
