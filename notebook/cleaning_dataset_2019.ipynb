# %%
import pandas as pd

# %%
df_2019 = pd.read_csv("../resources/raw_data/dataset_2019_raw.csv")

# %%
print(df_2019.shape)
df_2019.head()
# Out:
# (352, 82)
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# ...

# %%
#df_2019.info()
# Drop columns with more than 75% null values(except state_live and ethnicity):
columns_to_drop = ["Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.", "Describe the conversation with coworkers you had about your mental health including their reactions.", "Describe the conversation your coworker had with you about their mental health (please do not use names).", "Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?", "Do you know local or online resources to seek help for a mental health issue?",
                  "If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?", "If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?", "If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?", "If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?",
                  "Do you believe your productivity is ever affected by a mental health issue?", "If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?", "Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.", 
                  "Describe the conversation you had with your previous coworkers about your mental health including their reactions.", "Describe the conversation your coworker had with you about their mental health (please do not use names).", "Have you ever been *diagnosed* with a mental health disorder?", "*What disorder(s) have you been diagnosed with?*",
                  "*If possibly, what disorder(s) do you believe you have?*", "*If so, what disorder(s) were you diagnosed with?*", "Has being identified as a person with a mental health issue affected your career?", "How has it affected your career?", "Describe the circumstances of the supportive or well handled response.",'Would you have been willing to discuss your mental health with your coworkers at previous employers?',
                   "Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.", "If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.",'Have you ever discussed your mental health with coworkers?','Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)']

# %%
df_2019_drop = df_2019.drop(columns = columns_to_drop)

#Check:
print(df_2019_drop.shape)
print(df_2019_drop.columns.tolist())
# Out:
# (352, 57)
# ...

# %%
# Rename columns:
cols = {'*Are you self-employed?*':"self_employed",'How many employees does your company or organization have?':"company_size",'Is your employer primarily a tech company/organization?':"tech_or_not",'Is your primary role within your company related to tech/IT?':"tech_it",
       'Does your employer provide mental health benefits as part of healthcare coverage?':"employer_provide_coverage",'Do you know the options for mental health care available under your employer-provided health coverage?':"mh_care_options_coverage",'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?':"wellness_program_discuss",
       'Does your employer offer resources to learn more about mental health disorders and options for seeking help?':"resources_mh_help","'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?'":"anonymity_protected_mh_treatment",'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?':"leave",
       'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?':"talk_ph_mh_coworkers",'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?':"talk_mh_supervisors",'Have you ever discussed your mental health with your employer?':"talk_mh_employer",'Would you feel comfortable discussing a mental health issue with your coworkers?':"talk_mh_coworkers","Have you ever had a coworker discuss their or another coworker's mental health with you?":"coworker_discuss_mh",
       'Overall, how much importance does your employer place on physical health?':"importance_ph_employer",'Overall, how much importance does your employer place on mental health?':"importance_mh_employer",'*Do you have previous employers?*':"previous_employer",
       'Was your employer primarily a tech company/organization?':"prev_tech_or_not",'Have your previous employers provided mental health benefits?':"prev_mh_coverage",'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?':"prev_wellness_program_discuss",'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?':"prev_resources_mh_help",'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?':"prev_anonymity_mh_treatment",
       'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?':"prev_discuss_ph_mh",'Would you have been willing to discuss your mental health with your direct supervisor(s)?':"prev_discuss_mh_supervisors",'Did you ever discuss your mental health with your previous employer?':"prev_discuss_employer",'Did you ever discuss your mental health with a previous coworker(s)?':"prev_discuss_coworkers","Did you ever have a previous coworker discuss their or another coworker's mental health with you?":"prev_coworkers_discuss_mh",
       'Describe the conversation your coworker had with you about their mental health (please do not use names)..1':"describe_conversation",'Overall, how much importance did your previous employer place on physical health?':"prev_employer_importance_ph",'Overall, how much importance did your previous employer place on mental health?':"prev_emploey_importance_mh",'Do you *currently* have a mental health disorder?':"currently_dx_mh",'Have you had a mental health disorder in the past?':"past_mh_disorder",'Have you ever sought treatment for a mental health disorder from a mental health professional?':"treatment_for_mh_by_mh_professional",'Do you have a family history of mental illness?':"mh_family_history",
       'If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*':"if_mh_treated_effectively_interfere_work",'If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*':"if_mh_not_treated_effectively_interfere_work",'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?':"not_reveal_mh_because_observations",'How willing would you be to share with friends and family that you have a mental illness?':"share_mh_family_friends",
       'Would you be willing to bring up a physical health issue with a potential employer in an interview?':"interview_ph",'Why or why not?':"why_why_not_ph",'Would you bring up your *mental* health with a potential employer in an interview?':"interview_mh",'Why or why not?.1':"why_why_not_mh",'Are you openly identified at work as a person with a mental health issue?':"identified_work_mh_individual",'If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?':"reaction_towards_mh",'Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?':"employer_unsuportive_response_mh",
       'Describe the circumstances of the badly handled or unsupportive response.':"unsuportive_desciption",'Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?':"employer_suportive_response_mh",'Overall, how well do you think the tech industry supports employees with mental health issues?':"tech_industry_support_mh_issues",'What is your age?':"age",'What is your gender?':"gender",'What country do you *live* in?':"country_live", 'What US state or territory do you *live* in?':"state_live",'What is your race?':"ethnicity",'What country do you *work* in?':"country_work",'What US state or territory do you *work* in?':"state_work"}

# %%
# Rename columns and add unique identifier columns:
df_2019_clean = df_2019_drop.rename(columns = cols)
df_2019_clean["key"] = 45

# %%
# Check:
print(df_2019_clean.columns.tolist())
df_2019_clean.head()
# Out:
# ['self_employed', 'company_size', 'tech_or_not', 'tech_it', 'employer_provide_coverage', 'mh_care_options_coverage', 'wellness_program_discuss', 'resources_mh_help', 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?', 'leave', 'talk_ph_mh_coworkers', 'talk_mh_supervisors', 'talk_mh_employer', 'talk_mh_coworkers', 'coworker_discuss_mh', 'importance_ph_employer', 'importance_mh_employer', 'previous_employer', 'prev_tech_or_not', 'prev_mh_coverage', 'Were you aware of the options for mental health care provided by your previous employers?', 'prev_wellness_program_discuss', 'prev_resources_mh_help', 'prev_anonymity_mh_treatment', 'prev_discuss_ph_mh', 'prev_discuss_mh_supervisors', 'prev_discuss_employer', 'prev_discuss_coworkers', 'prev_coworkers_discuss_mh', 'describe_conversation', 'prev_employer_importance_ph', 'prev_emploey_importance_mh', 'currently_dx_mh', 'past_mh_disorder', 'treatment_f
# ...

# %%
# Export as csv:
df_2019_clean.to_csv("../resources/upload_in_database/dataset_2019.csv")

# %%
df_2019_clean.head()
# Out:
#    self_employed company_size tech_or_not tech_it employer_provide_coverage  \
# 0          False       26-100        True    True              I don't know
# 1          False       26-100        True    True                       Yes
# 2          False       26-100        True    True              I don't know
# 3          False      100-500        True    True              I don't know
# 4          False       26-100        True    True              I don't know
#
#   mh_care_options_coverage wellness_program_discuss resources_mh_help  \
# 0                       No                      Yes               Yes
# 1                       No                       No               Yes
# 2                       No                       No      I don't know
# 3                       No                      Yes               Yes
# 4                       No             I don't know      I don't know
#
# ...
