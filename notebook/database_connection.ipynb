# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from config import password

# %%
# Read dataset after columns renamed:
df = pd.read_csv("../resources/OSMI_MHIT_clean_not_encoded.csv")
df.head()
# Out:
#    Unnamed: 0  self_employed company_size  tech_company  tech_role  \
# 0           1              0       26-100           1.0        NaN
# 1           2              0         6-25           1.0        NaN
# 2           3              0         6-25           1.0        NaN
# 3           4              1          NaN           NaN        NaN
# 4           5              0         6-25           0.0        1.0
#
#                        mh_coverage mh_coverage_awareness  \
# 0  Not eligible for coverage / N/A                   NaN
# 1                               No                   Yes
# 2                               No                   NaN
# 3                              NaN                   NaN
# 4                              Yes                   Yes
#
#   mh_employer_discussion mh_resources_provided  mh_anonimity  ...  \
# 0                     No                    No  I don't know  ...
# 1                    Yes                   Yes           Yes  ...
# ...

# %%
# Create engine and link to local postgres database:
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Mental_Health_vs_Economics')
connect = engine.connect()

# %%
#print(df.columns.tolist())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 64 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             1433 non-null   int64
#  1   self_employed                          1433 non-null   int64
#  2   company_size                           1146 non-null   object
#  3   tech_company                           1146 non-null   float64
#  4   tech_role                              263 non-null    float64
#  5   mh_coverage                            1146 non-null   object
#  6   mh_coverage_awareness                  1013 non-null   object
#  7   mh_employer_discussion                 1146 non-null   object
#  8   mh_resources_provided                  1146 non-null   object
#  9   mh_anonimity                           1146 non-null   object
# ...

# %%
from sqlalchemy.types import Integer, Text, String, DateTime

# %%
# Log-in dataset after columns renamed and first row drop:
table_name = "dataset_raw"
df.to_sql(
    table_name,
    engine,
    if_exists = "replace")

# %%
# Create session:
session = Session(engine)

# %%
# Reflect an existing database into a new model:
Base = automap_base()

# Reflect the tables:
Base.prepare(engine, reflect=True)

Base.classes.keys()
# Out:
# []

# %%
df = pd.read_sql("SELECT live_us_state FROM dataset_raw", connect)
df.head()
# Out:
#   live_us_state
# 0          None
# 1      Illinois
# 2          None
# 3          None
# 4      Illinois
