# %%
import pandas as pd
from sqlalchemy import create_engine
from config import password
import psycopg2
import pandas.io.sql as sqlio

# %%
param_dic={
    "host": "mht.ciic7sa0kxc0.us-west-2.rds.amazonaws.com",
    "database": "postgres",
    "user" : "postgres",
    "password" : password
}

def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

conn = connect(param_dic)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %%
query="select * from survey"

survey_df=sqlio.read_sql_query(query,conn)

survey_df.head()
# Out:
#    SurveyID                    Description
# 0      2014  mental health survey for 2014
# 1      2016  mental health survey for 2016
# 2      2017  mental health survey for 2017
# 3      2018  mental health survey for 2018
# 4      2019  mental health survey for 2019

# %%
query="select * from survey_2014"

survey2014_df=sqlio.read_sql_query(query,conn)

survey2014_df.head()
# Out:
#    index age  gender         country state self_employed family_history  \
# 0      0  37  Female   United States    IL          None             No
# 1      1  44       M   United States    IN          None             No
# 2      2  32    Male          Canada  None          None             No
# 3      3  31    Male  United Kingdom  None          None            Yes
# 4      4  31    Male   United States    TX          None             No
#
#   treatment work_interfere    no_employees  ...               leave  \
# 0       Yes          Often          25-Jun  ...       Somewhat easy
# 1        No         Rarely  More than 1000  ...          Don't know
# 2        No         Rarely          25-Jun  ...  Somewhat difficult
# 3       Yes          Often          26-100  ...  Somewhat difficult
# 4        No          Never         100-500  ...          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %%
query="select * from survey_2016"

survey2016_df=sqlio.read_sql_query(query,conn)

survey2016_df.head()
# Out:
#    SurveyID  new_id  self_employed    company_size  tech_company  \
# 0      2016       1              0          26-100             1
# 1      2016       2              0          25-Jun             1
# 2      2016       3              0          25-Jun             1
# 3      2016       4              0          25-Jun             0
# 4      2016       5              0  More than 1000             1
#
#                        mh_coverage mh_coverage_awareness  \
# 0  Not eligible for coverage / N/A         I am not sure
# 1                               No                   Yes
# 2                               No         I am not sure
# 3                              Yes                   Yes
# 4                              Yes         I am not sure
#
#   mh_employer_discussion mh_resources_provided  mh_anonimity  ... age  gender  \
# 0                     No                    No  I don't know  ...  39    male
# ...

# %%
query="select * from survey_2017"

survey2017_df=sqlio.read_sql_query(query,conn)

survey2017_df.head()
# Out:
#    SurveyID  self_employed    company_size  tech_or_not  related_tech_it  \
# 0      2017              0         100-500          1.0              1.0
# 1      2017              0         100-500          1.0              1.0
# 2      2017              0          25-Jun          1.0              1.0
# 3      2017              0  More than 1000          1.0              1.0
# 4      2017              1            None          NaN              NaN
#
#   employer_provide_mh_coverage employer_discus_mh employers_options_help  \
# 0                           No                 No           I don't know
# 1                          Yes                 No                     No
# 2                 I don't know       I don't know                     No
# 3                          Yes       I don't know           I don't know
# 4                         None               None                   None
#
#   protected_anonymity_mh         leave  ... suportive_response_to_mh  \
# ...

# %%
query="select * from survey_2019"

survey2019_df=sqlio.read_sql_query(query,conn)

survey2019_df.head()
# Out:
#    SurveyID  self_employed company_size tech_or_not tech_it  \
# 0      2019          False       26-100        True    True
# 1      2019          False       26-100        True    True
# 2      2019          False       26-100        True    True
# 3      2019          False      100-500        True    True
# 4      2019          False       26-100        True    True
#
#   employer_provide_coverage mh_care_options_coverage wellness_program_discuss  \
# 0              I don't know                       No                      Yes
# 1                       Yes                       No                       No
# 2              I don't know                       No                       No
# 3              I don't know                       No                      Yes
# 4              I don't know                       No             I don't know
#
#   resources_mh_help anonymity_protected_mh_treatment  ...  \
# 0               Yes                     I don't know  ...
# ...
