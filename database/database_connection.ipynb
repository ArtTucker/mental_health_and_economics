# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy.types import Integer, Text, String, DateTime
from config import password

# %% [markdown]
# #### Clean and load OSMI_2014_survey:

# %%
# Rename columns(2014):
cols = ["age","gender", "country", "state", "self_employed",
        "family_history", "treatment", "work_interfere", "no_employees", "remote_work", 
        "tech_company", "benefits", "care_options", "wellness_program", "seek_help", 
        "anonymity", "leave", "mental_health_consequence", "phys_health_consequence", "coworkers", 
        "supervisor", "mental_health_interview", "phys_health_interview", "mental_vs_physical", 
        "obs_consequence", "comments"]

# %%
# Read 2014 survey and rename columns:
df_2014 = pd.read_csv("../resources/dataset_2014.csv", names = cols)
df_2014.head()
# Out:
#                  age  gender         country  \
# Timestamp        Age  Gender         Country
# 8/27/2014 11:29   37  Female   United States
# 8/27/2014 11:29   44       M   United States
# 8/27/2014 11:29   32    Male          Canada
# 8/27/2014 11:29   31    Male  United Kingdom
#
#                                                              state  \
# Timestamp        If you live in the United States, which state ...
# 8/27/2014 11:29                                                 IL
# 8/27/2014 11:29                                                 IN
# 8/27/2014 11:29                                                NaN
# 8/27/2014 11:29                                                NaN
#
#                           self_employed  \
# Timestamp        Are you self-employed?
# 8/27/2014 11:29                     NaN
# 8/27/2014 11:29                     NaN
# 8/27/2014 11:29                     NaN
# 8/27/2014 11:29                     NaN
#
#                                                   family_history  \
# Timestamp        Do you have a family history of mental illness?
# 8/27/2014 11:29                                               No
# 8/27/2014 11:29                                               No
# 8/27/2014 11:29                                               No
# 8/27/2014 11:29                                              Yes
#
#                                                          treatment  \
# Timestamp        Have you sought treatment for a mental health ...
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
#
#                                                     work_interfere  \
# Timestamp        If you have a mental health condition, do you ...
# 8/27/2014 11:29                                              Often
# 8/27/2014 11:29                                             Rarely
# 8/27/2014 11:29                                             Rarely
# 8/27/2014 11:29                                              Often
#
#                                                       no_employees  \
# Timestamp        How many employees does your company or organi...
# 8/27/2014 11:29                                             25-Jun
# 8/27/2014 11:29                                     More than 1000
# 8/27/2014 11:29                                             25-Jun
# 8/27/2014 11:29                                             26-100
#
#                                                        remote_work  ...  \
# Timestamp        Do you work remotely (outside of an office) at...  ...
# 8/27/2014 11:29                                                 No  ...
# 8/27/2014 11:29                                                 No  ...
# 8/27/2014 11:29                                                 No  ...
# 8/27/2014 11:29                                                 No  ...
#
#                                                              leave  \
# Timestamp        How easy is it for you to take medical leave f...
# 8/27/2014 11:29                                      Somewhat easy
# 8/27/2014 11:29                                         Don't know
# 8/27/2014 11:29                                 Somewhat difficult
# 8/27/2014 11:29                                 Somewhat difficult
#
#                                          mental_health_consequence  \
# Timestamp        Do you think that discussing a mental health i...
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                              Maybe
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
#
#                                            phys_health_consequence  \
# Timestamp        Do you think that discussing a physical health...
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
#
#                                                          coworkers  \
# Timestamp        Would you be willing to discuss a mental healt...
# 8/27/2014 11:29                                       Some of them
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                       Some of them
#
#                                                         supervisor  \
# Timestamp        Would you be willing to discuss a mental healt...
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                                 No
#
#                                            mental_health_interview  \
# Timestamp        Would you bring up a mental health issue with ...
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                              Maybe
#
#                                              phys_health_interview  \
# Timestamp        Would you bring up a physical health issue wit...
# 8/27/2014 11:29                                              Maybe
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                              Maybe
#
#                                                 mental_vs_physical  \
# Timestamp        Do you feel that your employer takes mental he...
# 8/27/2014 11:29                                                Yes
# 8/27/2014 11:29                                         Don't know
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
#
#                                                    obs_consequence  \
# Timestamp        Have you heard of or observed negative consequ...
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                 No
# 8/27/2014 11:29                                                Yes
#
#                                          comments
# Timestamp        Any additional notes or comments
# 8/27/2014 11:29                               NaN
# 8/27/2014 11:29                               NaN
# 8/27/2014 11:29                               NaN
# 8/27/2014 11:29                               NaN
#
# [5 rows x 26 columns]

# %%
# Drop duplicate header:
df_2014.drop(df_2014.index[0], inplace = True)

# %%
# Drop index:
df_2014.reset_index(drop = True, inplace = True)

# %%
# Drop Timestamp columns:
df_2014.drop(columns = "Timestamp", axis = 1, inplace = True)

# %%
# Add year  for interaction between table:
df_2014["year"] = 2014

# %%
# Check:
print(df_2014.shape)
df_2014.head()
# Out:
# (1260, 27)
#   age  gender         country state self_employed family_history treatment  \
# 0  37  Female   United States    IL           NaN             No       Yes
# 1  44       M   United States    IN           NaN             No        No
# 2  32    Male          Canada   NaN           NaN             No        No
# 3  31    Male  United Kingdom   NaN           NaN            Yes       Yes
# 4  31    Male   United States    TX           NaN             No        No
#
#   work_interfere    no_employees remote_work  ... mental_health_consequence  \
# 0          Often          25-Jun          No  ...                        No
# 1         Rarely  More than 1000          No  ...                     Maybe
# 2         Rarely          25-Jun          No  ...                        No
# 3          Often          26-100          No  ...                       Yes
# 4          Never         100-500         Yes  ...                        No
#
#   phys_health_consequence     coworkers supervisor mental_health_interview  \
# 0                      No  Some of them        Yes                      No
# 1                      No            No         No                      No
# 2                      No           Yes        Yes                     Yes
# 3                     Yes  Some of them         No                   Maybe
# 4                      No  Some of them        Yes                     Yes
#
#   phys_health_interview mental_vs_physical obs_consequence comments  year
# 0                 Maybe                Yes              No      NaN  2014
# 1                    No         Don't know              No      NaN  2014
# 2                   Yes                 No              No      NaN  2014
# 3                 Maybe                 No             Yes      NaN  2014
# 4                   Yes         Don't know              No      NaN  2014
#
# [5 rows x 27 columns]

# %%
# Create engine and link to local postgres database:
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Final_project_mental_health')
connect = engine.connect()

# %%
# Log-in dataset_2014:
table_name = "dataset_2014"
df_2014.to_sql(
    table_name,
    engine,
    if_exists = "replace")

# Create session:
session = Session(engine)

# %%
# Check:
test_df = pd.read_sql("SELECT age FROM dataset_2014", connect)
test_df.head()
# Out:
#   age
# 0  37
# 1  44
# 2  32
# 3  31
# 4  31

# %% [markdown]
# #### Clean and load OSMI_2016_survey:

# %%
# Rename columns(2014):
cols = ['self_employed', 'company_size', 'tech_company', 'tech_role', 'mh_coverage',
        'mh_coverage_awareness', 'mh_employer_discussion', 'mh_resources_provided', 'mh_anonimity',
        'mh_medical_leave', 'mh_discussion_negative_impact', 'ph_discussion_negative_impact', 'mh_discussion_coworkers',
        'mh_discussion_supervisors', 'mh_equal_ph', 'mh_observed_consequences_coworkers', 'mh_coverage_2', 'mh_online_resources',
        'mh_dx_revealed_clients', 'mh_dx_revealed_clients_impact', 'mh_dx_revealed_coworkers', 'mh_coworkers_reveal_negative_impact',
        'mh_product_impact', 'mh_product_impact_perceived', 'prev_employers', 'prev_mh_benefits', 'prev_mh_benefits_awareness',
        'prev_mh_discussion', 'prev_mh_resources', 'prev_mh_anonimity', 'prev_mh_discuss_negative_consequences', 'prev_ph_discuss_negative_consequences',
        'prev_mh_discussion_coworkers', 'prev_mh_discussion_supervisors', 'prev_mh_importance_employer', 'prev_mh_consequences_coworkers',
        'future_ph_specification', 'why_why_not', 'future_mh_specification', 'why_why_not2', 'mh_hurt_on_career', 'mh_neg_view_coworkers',
        'mh_sharing_friends_family', 'mh_bad_response_workplace', 'mh_for_others_bad_response_workplace', 'mh_family_history',
        'mh_dx_past', 'mh_dx_current', 'yes_what_dx?', 'maybe_whats_your_dx', 'mh_dx_pro',
        'yes_condition_dx', 'mh_sought_pro_tx', 'mh_eff_tx_impact_on_work', 'mh_not_eff_tx_impact_on_work',
        'age', 'gender', 'country_live', 'live_us_state', 'country_work', 'work_us_state', 'work_position', 'remote']

# %%
# Read 2016 survey and rename columns:
df_2016 = pd.read_csv("../resources/dataset_2016.csv", names = cols)
df_2016.head()
# Out:
#             self_employed                                       company_size  \
# 0  Are you self-employed?  How many employees does your company or organi...
# 1                       0                                             26-100
# 2                       0                                               6-25
# 3                       0                                               6-25
# 4                       1                                                NaN
#
#                                         tech_company  \
# 0  Is your employer primarily a tech company/orga...
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                NaN
#
#                                            tech_role  \
# 0  Is your primary role within your company relat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          mh_coverage  \
# 0  Does your employer provide mental health benef...
# 1                    Not eligible for coverage / N/A
# 2                                                 No
# 3                                                 No
# 4                                                NaN
#
#                                mh_coverage_awareness  \
# 0  Do you know the options for mental health care...
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                NaN
#
#                               mh_employer_discussion  \
# 0  Has your employer ever formally discussed ment...
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                NaN
#
#                                mh_resources_provided  \
# 0  Does your employer offer resources to learn mo...
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                NaN
#
#                                         mh_anonimity  \
# 0  Is your anonymity protected if you choose to t...
# 1                                       I don't know
# 2                                                Yes
# 3                                       I don't know
# 4                                                NaN
#
#                                     mh_medical_leave  ...  \
# 0  If a mental health issue prompted you to reque...  ...
# 1                                          Very easy  ...
# 2                                      Somewhat easy  ...
# 3                         Neither easy nor difficult  ...
# 4                                                NaN  ...
#
#                             mh_eff_tx_impact_on_work  \
# 0  If you have a mental health issue, do you feel...
# 1                               Not applicable to me
# 2                                             Rarely
# 3                               Not applicable to me
# 4                                          Sometimes
#
#                         mh_not_eff_tx_impact_on_work                age  \
# 0  If you have a mental health issue, do you feel...  What is your age?
# 1                               Not applicable to me                 39
# 2                                          Sometimes                 29
# 3                               Not applicable to me                 38
# 4                                          Sometimes                 43
#
#                  gender                  country_live  \
# 0  What is your gender?  What country do you live in?
# 1                  Male                United Kingdom
# 2                  male      United States of America
# 3                 Male                 United Kingdom
# 4                  male                United Kingdom
#
#                                 live_us_state                  country_work  \
# 0  What US state or territory do you live in?  What country do you work in?
# 1                                         NaN                United Kingdom
# 2                                    Illinois      United States of America
# 3                                         NaN                United Kingdom
# 4                                         NaN                United Kingdom
#
#                                 work_us_state  \
# 0  What US state or territory do you work in?
# 1                                         NaN
# 2                                    Illinois
# 3                                         NaN
# 4                                         NaN
#
#                                        work_position                 remote
# 0  Which of the following best describes your wor...  Do you work remotely?
# 1                                 Back-end Developer              Sometimes
# 2             Back-end Developer|Front-end Developer                  Never
# 3                                 Back-end Developer                 Always
# 4                               Supervisor/Team Lead              Sometimes
#
# [5 rows x 63 columns]

# %%
# Drop duplicate header:
df_2016.drop(df_2016.index[0], inplace = True)

# %%
# Add year  for interaction between table:
df_2016["year"] = 2016

# %%
# Check:
print(df_2016.shape)
df_2016.head()
# Out:
# (1433, 64)
#   self_employed company_size tech_company tech_role  \
# 1             0       26-100            1       NaN
# 2             0         6-25            1       NaN
# 3             0         6-25            1       NaN
# 4             1          NaN          NaN       NaN
# 5             0         6-25            0         1
#
#                        mh_coverage mh_coverage_awareness  \
# 1  Not eligible for coverage / N/A                   NaN
# 2                               No                   Yes
# 3                               No                   NaN
# 4                              NaN                   NaN
# 5                              Yes                   Yes
#
#   mh_employer_discussion mh_resources_provided  mh_anonimity  \
# 1                     No                    No  I don't know
# 2                    Yes                   Yes           Yes
# 3                     No                    No  I don't know
# 4                    NaN                   NaN           NaN
# 5                     No                    No            No
#
#              mh_medical_leave  ... mh_not_eff_tx_impact_on_work age  gender  \
# 1                   Very easy  ...         Not applicable to me  39    Male
# 2               Somewhat easy  ...                    Sometimes  29    male
# 3  Neither easy nor difficult  ...         Not applicable to me  38   Male
# 4                         NaN  ...                    Sometimes  43    male
# 5  Neither easy nor difficult  ...                    Sometimes  43  Female
#
#                country_live live_us_state              country_work  \
# 1            United Kingdom           NaN            United Kingdom
# 2  United States of America      Illinois  United States of America
# 3            United Kingdom           NaN            United Kingdom
# 4            United Kingdom           NaN            United Kingdom
# 5  United States of America      Illinois  United States of America
#
#   work_us_state                                      work_position     remote  \
# 1           NaN                                 Back-end Developer  Sometimes
# 2      Illinois             Back-end Developer|Front-end Developer      Never
# 3           NaN                                 Back-end Developer     Always
# 4           NaN                               Supervisor/Team Lead  Sometimes
# 5      Illinois  Executive Leadership|Supervisor/Team Lead|Dev ...  Sometimes
#
#    year
# 1  2016
# 2  2016
# 3  2016
# 4  2016
# 5  2016
#
# [5 rows x 64 columns]

# %%
# Log-in dataset_2016:
table_name = "dataset_2016"
df_2016.to_sql(
    table_name,
    engine,
    if_exists = "replace")

# %%
# Check:
test_df1 = pd.read_sql("SELECT age FROM dataset_2016", connect)
test_df1.head()
# Out:
#   age
# 0  39
# 1  29
# 2  38
# 3  43
# 4  43

# %% [markdown]
# #### Clean and load OSMI_2017_survey:

# %%
df_2017 = pd.read_csv("../resources/dataset_2017.csv")
df_2017.head()
# Out:
#    Unnamed: 0  self_employed    company_size  tech_or_not  related_tech_it  \
# 0           0              0         100-500          1.0              1.0
# 1           1              0         100-500          1.0              1.0
# 2           2              0            6-25          1.0              1.0
# 3           3              0  More than 1000          1.0              1.0
# 4           4              1             NaN          NaN              NaN
#
#   employer_provide_mh_coverage employer_discus_mh employers_options_help  \
# 0                           No                 No           I don't know
# 1                          Yes                 No                     No
# 2                 I don't know       I don't know                     No
# 3                          Yes       I don't know           I don't know
# 4                          NaN                NaN                    NaN
#
#   protected_anonymity_mh         leave  ... unsuportive_reponse_to_mh  \
# 0           I don't know  I don't know  ...        Yes, I experienced
# 1           I don't know  I don't know  ...           Yes, I observed
# 2                    Yes     Difficult  ...        Yes, I experienced
# 3                    Yes     Difficult  ...            Maybe/Not sure
# 4                    NaN           NaN  ...                        No
#
#    suportive_response_to_mh tech_industry_support_mh   age  gender  \
# 0        Yes, I experienced                      1.0  27.0  Female
# 1            Maybe/Not sure                      2.0  31.0    male
# 2        Yes, I experienced                      1.0  36.0    male
# 3            Maybe/Not sure                      2.0  22.0    Male
# 4           Yes, I observed                      1.0  52.0  female
#
#                country_live  state_live                   ethnicity  \
# 0            United Kingdom         NaN                         NaN
# 1            United Kingdom         NaN                         NaN
# 2  United States of America    Missouri                       White
# 3  United States of America  Washington                       White
# 4  United States of America    Illinois  More than one of the above
#
#                country_work  state_work
# 0            United Kingdom         NaN
# 1            United Kingdom         NaN
# 2  United States of America    Missouri
# 3  United States of America  Washington
# 4  United States of America    Illinois
#
# [5 rows x 49 columns]

# %%
df_2017.columns.tolist()
df_2017.drop(columns = "Unnamed: 0", inplace = True)
df_2017["year"] = 2017

# %%
# Check:
df_2017.head()
# Out:
#    self_employed    company_size  tech_or_not  related_tech_it  \
# 0              0         100-500          1.0              1.0
# 1              0         100-500          1.0              1.0
# 2              0            6-25          1.0              1.0
# 3              0  More than 1000          1.0              1.0
# 4              1             NaN          NaN              NaN
#
#   employer_provide_mh_coverage employer_discus_mh employers_options_help  \
# 0                           No                 No           I don't know
# 1                          Yes                 No                     No
# 2                 I don't know       I don't know                     No
# 3                          Yes       I don't know           I don't know
# 4                          NaN                NaN                    NaN
#
#   protected_anonymity_mh         leave mh_supervisor  ...  \
# 0           I don't know  I don't know           Yes  ...
# 1           I don't know  I don't know         Maybe  ...
# 2                    Yes     Difficult           Yes  ...
# 3                    Yes     Difficult           Yes  ...
# 4                    NaN           NaN           NaN  ...
#
#    suportive_response_to_mh tech_industry_support_mh   age  gender  \
# 0        Yes, I experienced                      1.0  27.0  Female
# 1            Maybe/Not sure                      2.0  31.0    male
# 2        Yes, I experienced                      1.0  36.0    male
# 3            Maybe/Not sure                      2.0  22.0    Male
# 4           Yes, I observed                      1.0  52.0  female
#
#                country_live  state_live                   ethnicity  \
# 0            United Kingdom         NaN                         NaN
# 1            United Kingdom         NaN                         NaN
# 2  United States of America    Missouri                       White
# 3  United States of America  Washington                       White
# 4  United States of America    Illinois  More than one of the above
#
#                country_work  state_work  year
# 0            United Kingdom         NaN  2017
# 1            United Kingdom         NaN  2017
# 2  United States of America    Missouri  2017
# 3  United States of America  Washington  2017
# 4  United States of America    Illinois  2017
#
# [5 rows x 49 columns]

# %%
# Log-in dataset_2017:
table_name = "dataset_2017"
df_2017.to_sql(
    table_name,
    engine,
    if_exists = "replace")

# %%
# Check:
test_df2 = pd.read_sql("SELECT age FROM dataset_2017", connect)
test_df2.head()
# Out:
#     age
# 0  27.0
# 1  31.0
# 2  36.0
# 3  22.0
# 4  52.0
