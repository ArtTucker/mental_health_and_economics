# %%
import pandas as pd
import numpy as np
from pathlib import Path
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(Path('../resources/OSMI_MHIT_mostly_clean.csv')).set_index('new_id')
df
# Out:
#         self_employed    company_size  tech_company  \
# new_id
# 1                   0          26-100             1
# 2                   0            6-25             1
# 3                   0            6-25             1
# 4                   0            6-25             0
# 5                   0  More than 1000             1
# ...               ...             ...           ...
# 1003                0         100-500             1
# 1004                0        500-1000             1
# 1005                0         100-500             1
# 1006                0         100-500             0
# 1007                0         100-500             1
#
#                             mh_coverage mh_coverage_awareness  \
# new_id
# 1       Not eligible for coverage / N/A         I am not sure
# 2                                    No                   Yes
# 3                                    No         I am not sure
# 4                                   Yes                   Yes
# 5                                   Yes         I am not sure
# ...                                 ...                   ...
# 1003                       I don't know         I am not sure
# 1004                                Yes                    No
# 1005                                Yes                   Yes
# 1006                       I don't know         I am not sure
# 1007                                Yes                    No
#
#        mh_employer_discussion mh_resources_provided  mh_anonimity  \
# new_id
# 1                          No                    No  I don't know
# 2                         Yes                   Yes           Yes
# 3                          No                    No  I don't know
# 4                          No                    No            No
# 5                          No                   Yes           Yes
# ...                       ...                   ...           ...
# 1003                       No          I don't know  I don't know
# 1004                       No                    No           Yes
# 1005                      Yes                   Yes  I don't know
# 1006                       No                   Yes  I don't know
# 1007                       No                    No  I don't know
#
#                   mh_medical_leave mh_discussion_negative_impact  ... age  \
# new_id                                                            ...
# 1                        Very easy                            No  ...  39
# 2                    Somewhat easy                            No  ...  29
# 3       Neither easy nor difficult                         Maybe  ...  38
# 4       Neither easy nor difficult                           Yes  ...  43
# 5                    Somewhat easy                           Yes  ...  42
# ...                            ...                           ...  ...  ..
# 1003                 Somewhat easy                         Maybe  ...  26
# 1004                 Somewhat easy                            No  ...  38
# 1005            Somewhat difficult                         Maybe  ...  52
# 1006            Somewhat difficult                         Maybe  ...  30
# 1007                Very difficult                         Maybe  ...  25
#
#            gender              country_live live_us_state  \
# new_id
# 1            male            United Kingdom          none
# 2            male  United States of America      Illinois
# 3            male            United Kingdom          none
# 4          female  United States of America      Illinois
# 5            male            United Kingdom          none
# ...           ...                       ...           ...
# 1003       female                    Canada          none
# 1004       female  United States of America      Illinois
# 1005         male  United States of America       Georgia
# 1006       female  United States of America      Nebraska
# 1007    nonbinary                    Canada          none
#
#                     country_work  work_us_state  \
# new_id
# 1                 United Kingdom           none
# 2       United States of America       Illinois
# 3                 United Kingdom           none
# 4       United States of America       Illinois
# 5                 United Kingdom           none
# ...                          ...            ...
# 1003                      Canada           none
# 1004    United States of America       Illinois
# 1005    United States of America        Georgia
# 1006    United States of America       Nebraska
# 1007                      Canada           none
#
#                                             work_position     remote  \
# new_id
# 1                                      Back-end Developer  Sometimes
# 2                  Back-end Developer|Front-end Developer      Never
# 3                                      Back-end Developer     Always
# 4       Executive Leadership|Supervisor/Team Lead|Dev ...  Sometimes
# 5       DevOps/SysAdmin|Support|Back-end Developer|Fro...  Sometimes
# ...                                                   ...        ...
# 1003                                                Other  Sometimes
# 1004                                              Support     Always
# 1005                                   Back-end Developer  Sometimes
# 1006                                      DevOps/SysAdmin  Sometimes
# 1007                                                Other  Sometimes
#
#         quantile_age_1 quantile_age_2
# new_id
# 1         (38.0, 99.0]   (37.0, 39.0]
# 2         (28.0, 32.0]   (27.0, 29.0]
# 3         (32.0, 38.0]   (37.0, 39.0]
# 4         (38.0, 99.0]   (39.0, 44.0]
# 5         (38.0, 99.0]   (39.0, 44.0]
# ...                ...            ...
# 1003    (19.999, 28.0]   (25.0, 27.0]
# 1004      (32.0, 38.0]   (37.0, 39.0]
# 1005      (38.0, 99.0]   (44.0, 99.0]
# 1006      (28.0, 32.0]   (29.0, 30.0]
# 1007    (19.999, 28.0]   (19.0, 25.0]
#
# [1004 rows x 53 columns]

# %%
#data types and counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1004 entries, 1 to 1007
# Data columns (total 53 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   self_employed                          1004 non-null   int64
#  1   company_size                           1004 non-null   object
#  2   tech_company                           1004 non-null   int64
#  3   mh_coverage                            1004 non-null   object
#  4   mh_coverage_awareness                  1004 non-null   object
#  5   mh_employer_discussion                 1004 non-null   object
#  6   mh_resources_provided                  1004 non-null   object
#  7   mh_anonimity                           1004 non-null   object
#  8   mh_medical_leave                       1004 non-null   object
#  9   mh_discussion_negative_impact          1004 non-null   object
#  10  ph_discussion_negative_impact          1004 non-null   object
#  11  mh_discussion_coworkers                1004 non-null   object
#  12  mh_discussion_supervisors              1004 non-null   object
#  13  mh_equal_ph                            1004 non-null   object
#  14  mh_observed_consequences_coworkers     1004 non-null   object
#  15  prev_employers                         1004 non-null   int64
#  16  prev_mh_benefits                       893 non-null    object
#  17  prev_mh_benefits_awareness             893 non-null    object
#  18  prev_mh_discussion                     893 non-null    object
#  19  prev_mh_resources                      893 non-null    object
#  20  prev_mh_anonimity                      893 non-null    object
#  21  prev_mh_discuss_negative_consequences  893 non-null    object
#  22  prev_ph_discuss_negative_consequences  893 non-null    object
#  23  prev_mh_discussion_coworkers           893 non-null    object
#  24  prev_mh_discussion_supervisors         893 non-null    object
#  25  prev_mh_importance_employer            893 non-null    object
#  26  prev_mh_consequences_coworkers         893 non-null    object
#  27  future_ph_specification                1004 non-null   object
#  28  future_mh_specification                1004 non-null   object
#  29  mh_hurt_on_career                      1004 non-null   object
#  30  mh_neg_view_coworkers                  1004 non-null   object
#  31  mh_sharing_friends_family              1004 non-null   object
#  32  mh_bad_response_workplace              1004 non-null   object
#  33  mh_for_others_bad_response_workplace   457 non-null    object
#  34  mh_family_history                      1004 non-null   object
#  35  mh_dx_past                             1004 non-null   object
#  36  mh_dx_current                          1004 non-null   object
#  37  yes_what_dx?                           420 non-null    object
#  38  mh_dx_pro                              1004 non-null   object
#  39  yes_condition_dx                       522 non-null    object
#  40  mh_sought_pro_tx                       1004 non-null   int64
#  41  mh_eff_tx_impact_on_work               1004 non-null   object
#  42  mh_not_eff_tx_impact_on_work           1004 non-null   object
#  43  age                                    1004 non-null   int64
#  44  gender                                 1004 non-null   object
#  45  country_live                           1004 non-null   object
#  46  live_us_state                          1004 non-null   object
#  47  country_work                           1004 non-null   object
#  48  work_us_state                          1004 non-null   object
#  49  work_position                          1004 non-null   object
#  50  remote                                 1004 non-null   object
#  51  quantile_age_1                         1004 non-null   object
#  52  quantile_age_2                         1004 non-null   object
# dtypes: int64(5), object(48)
# memory usage: 423.6+ KB

# %%
df.describe(include='all')
# Out:
#         self_employed company_size  tech_company mh_coverage  \
# count          1004.0         1004   1004.000000        1004
# unique            NaN            6           NaN           4
# top               NaN       26-100           NaN         Yes
# freq              NaN          263           NaN         510
# mean              0.0          NaN      0.764940         NaN
# std               0.0          NaN      0.424247         NaN
# min               0.0          NaN      0.000000         NaN
# 25%               0.0          NaN      1.000000         NaN
# 50%               0.0          NaN      1.000000         NaN
# 75%               0.0          NaN      1.000000         NaN
# max               0.0          NaN      1.000000         NaN
#
#        mh_coverage_awareness mh_employer_discussion mh_resources_provided  \
# count                   1004                   1004                  1004
# unique                     3                      3                     3
# top            I am not sure                     No                    No
# freq                     412                    708                   438
# mean                     NaN                    NaN                   NaN
# std                      NaN                    NaN                   NaN
# min                      NaN                    NaN                   NaN
# 25%                      NaN                    NaN                   NaN
# 50%                      NaN                    NaN                   NaN
# 75%                      NaN                    NaN                   NaN
# max                      NaN                    NaN                   NaN
#
#         mh_anonimity mh_medical_leave mh_discussion_negative_impact  ...  \
# count           1004             1004                          1004  ...
# unique             3                6                             3  ...
# top     I don't know    Somewhat easy                         Maybe  ...
# freq             649              241                           427  ...
# mean             NaN              NaN                           NaN  ...
# std              NaN              NaN                           NaN  ...
# min              NaN              NaN                           NaN  ...
# 25%              NaN              NaN                           NaN  ...
# 50%              NaN              NaN                           NaN  ...
# 75%              NaN              NaN                           NaN  ...
# max              NaN              NaN                           NaN  ...
#
#                 age gender              country_live live_us_state  \
# count   1004.000000   1004                      1004          1004
# unique          NaN      3                         6            48
# top             NaN   male  United States of America          none
# freq            NaN    722                       707           297
# mean      33.659363    NaN                       NaN           NaN
# std        8.086614    NaN                       NaN           NaN
# min       20.000000    NaN                       NaN           NaN
# 25%       28.000000    NaN                       NaN           NaN
# 50%       32.000000    NaN                       NaN           NaN
# 75%       38.000000    NaN                       NaN           NaN
# max       99.000000    NaN                       NaN           NaN
#
#                     country_work  work_us_state       work_position  \
# count                       1004           1004                1004
# unique                         7             49                 162
# top     United States of America           none  Back-end Developer
# freq                         709            295                 201
# mean                         NaN            NaN                 NaN
# std                          NaN            NaN                 NaN
# min                          NaN            NaN                 NaN
# 25%                          NaN            NaN                 NaN
# 50%                          NaN            NaN                 NaN
# 75%                          NaN            NaN                 NaN
# max                          NaN            NaN                 NaN
#
#            remote  quantile_age_1 quantile_age_2
# count        1004            1004           1004
# unique          3               4             10
# top     Sometimes  (19.999, 28.0]   (34.0, 37.0]
# freq          540             281            134
# mean          NaN             NaN            NaN
# std           NaN             NaN            NaN
# min           NaN             NaN            NaN
# 25%           NaN             NaN            NaN
# 50%           NaN             NaN            NaN
# 75%           NaN             NaN            NaN
# max           NaN             NaN            NaN
#
# [11 rows x 53 columns]

# %% [markdown]
# # Common Mental Health Disorders

# %%
df['yes_condition_dx'].value_counts()
# Out:
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                       140
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                   116
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                                                      50
# Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder                                                                                                               27
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder                                                           22
#                                                                                                                                                                                                        ...
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Post-traumatic Stress Disorder         1
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Post-traumatic Stress Disorder|Substance Use Disorder      1
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Eating Disorder (Anorexia, Bulimia, etc)|posttraumatic stress disourder                                                                               1
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Substance Use Disorder                                     1
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Obsessive-Compulsive Disorder                              1
# Name: yes_condition_dx, Length: 85, dtype: int64

# %%
disorders = {}

disorderCounts = dict(df['yes_condition_dx'].value_counts())
for i in disorderCounts:
    # get the disorders separately in case someone answered with more than one disorder
    disorderList = i.split('|')
    for j in disorderList:
        j = j.split(' (')[0]
        disorders[j] = disorders.get(j, 0) + disorderCounts[i]

tmp = pd.DataFrame()
for i in disorders:
    tmp = tmp.append([i] * disorders[i])

tmp[0] = tmp[0].replace([
    'Autism Spectrum Disorder', 'Autism - while not a "mental illness", still greatly affects how I handle anxiety',
    'autism spectrum disorder', 'PDD-NOS'], 'Autism')
tmp[0] = tmp[0].replace(['Aspergers', 'Asperger Syndrome'], "Asperger's Syndrome")
tmp[0] = tmp[0].replace(['posttraumatic stress disourder'], 'Post-traumatic Stress Disorder')
tmp[0] = tmp[0].replace(['ADD', 'Attention Deficit Disorder', 'attention deficit disorder'],
                       'Attention Deficit Hyperactivity Disorder')
tmp[0] = tmp[0].replace(['Schizotypal Personality Disorder'], 'Personality Disorder')
tmp[0] = tmp[0].replace(['Depression'], 'Mood Disorder')
tmp[0] = tmp[0].replace([
    'Autism', "Asperger's Syndrome", 'Intimate Disorder',
    'Seasonal Affective Disorder', 'Burn out', 'Gender Identity Disorder',
    'Suicidal Ideation', 'Gender Dysphoria', 'MCD'], 'Others')

# print(tmp[0].value_counts())
plt.figure(figsize=(16, 6))
g = sns.countplot(y=tmp[0], order=[
    'Mood Disorder', 'Anxiety Disorder', 'Attention Deficit Hyperactivity Disorder',
    'Post-traumatic Stress Disorder', 'Obsessive-Compulsive Disorder',
    'Stress Response Syndromes', 'Personality Disorder', 'Substance Use Disorder',
    'Eating Disorder', 'Addictive Disorder', 'Dissociative Disorder', 
    'Psychotic Disorder', 'Others'],palette="dark", alpha=.6,)
g.set_ylabel('Disorders')
g.set_title('Distribution of Mental Health Disorders')
plt.show()

# %% [markdown]
# Based on the survey results the most common mental health disorder appears to be
# mood disorder,followed by anxiety disorder.

# %% [markdown]
# # Gender Distribution Vs Country

# %%
df['tech_company'].value_counts()
# Out:
# 1    768
# 0    236
# Name: tech_company, dtype: int64

# %%
# Most respondents are male
plt.figure(figsize = (16,6))
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(20)
plt.subplots_adjust(wspace = 0)
fig.suptitle('Proportion of gender in tech', fontsize = 30, y=1.08)

# Barchart
sns.countplot(x = df[df['tech_company'] == 1]['country_live'], hue = df['gender'], ax = ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
ax1.set_title('Gender by Countries', pad = 20, fontsize = 20)
ax1.set_xlabel('Country', fontsize = 18)
ax1.set_ylabel('Count', fontsize = 18)
ax1.legend(['Male', 'Female', 'Other']);

# Pie Chart
all_techs = df[df['tech_company'] == 1]['gender'].count()
males = df[(df['tech_company'] == 1) & (df['gender'] == 'male')]['gender'].count()
females = df[(df['tech_company'] == 1) & (df['gender'] == 'female')]['gender'].count()
other = df[(df['tech_company'] == 1) & (df['gender'] == 'nonbinary')]['gender'].count()

labels = 'Male', 'Female', 'Other'
sizes = [males/all_techs, females/all_techs, other/all_techs]
colors = ['#73C6B6', '#F0B27A', '#7FB3D5']
explode = (0.09, 0, 0)  # explode 1st slice

ax2.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax2.axis('equal')
ax2.set_title('Overall gender prop%', pad = 20, fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Overall gender prop%')

# %% [markdown]
# Most of the Respondents in this survey are male,also According to women in tech statistics for 2020, men still outnumber women in the Engineering/Tech industry. A whopping 80% of those in the field are male, while only 20% are female.
